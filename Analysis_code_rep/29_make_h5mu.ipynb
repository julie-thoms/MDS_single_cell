# %% [markdown]
# # Making a h5mu file with all the mods

# %%
import scanpy as sc
import muon as mu
import anndata as ad

# %%
mdata_in = mu.read_h5mu("MDS_adata_for_publication_v2.h5mu")

# %%
mdata_in

# %%
p18 = sc.read("scvelo/p18_velocities.h5ad")
p17 = sc.read("scvelo/p17_velocities.h5ad")
p03 = sc.read("scvelo/p03_velocities.h5ad")
p09 = sc.read("scvelo/p09_velocities.h5ad")
p02 = sc.read("scvelo/p02_velocities.h5ad")
p01 = sc.read("scvelo/p01_velocities.h5ad")
p12 = sc.read("scvelo/p12_velocities.h5ad")
p08 = sc.read("scvelo/p08_velocities.h5ad")
p11 = sc.read("scvelo/p11_velocities.h5ad")

# %%
mdata_in.mod["scvelo_p18"] = p18.copy()
mdata_in.mod["scvelo_p17"] = p17.copy()
mdata_in.mod["scvelo_p03"] = p03.copy()
mdata_in.mod["scvelo_p09"] = p09.copy()
mdata_in.mod["scvelo_p02"] = p02.copy()
mdata_in.mod["scvelo_p01"] = p01.copy()
mdata_in.mod["scvelo_p12"] = p12.copy()
mdata_in.mod["scvelo_p08"] = p08.copy()
mdata_in.mod["scvelo_p11"] = p11.copy()
mdata_in.update()
mdata_in

# %%
mdata_in.write("MDS_mdata_for_publication_gex_prot_scvelo_v3.h5mu")
