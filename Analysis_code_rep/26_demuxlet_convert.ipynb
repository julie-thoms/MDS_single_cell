# %%
import pandas as pd

# %%
genotype_alias_dict = {'206902510049_R04C01': 'P11',
 '206902510049_R05C01': 'P12',
 '207071120017_R01C01': 'C5',
 '207071120017_R01C02': 'C4',
 '207071120017_R02C01': 'P11',
 '207071120017_R03C01': 'C1',
 '207071120017_R03C02': 'C3',
 '207071120017_R04C01': 'P15',
 '207071120017_R05C01': 'P12',
 '207071120017_R05C02': 'P08',
 '207071120017_R06C01': 'P17',
 '207071120017_R07C01': 'P03',
 '207071120017_R07C02': 'P10',
 '207071120017_R08C01': 'P18',
 '207071120017_R09C01': 'P09',
 '207071120017_R09C02': 'P02',
 '207071120017_R10C01': 'P13',
 '207071120017_R11C01': 'P01',
 '207071120017_R12C01': 'C2'}

# %%
infile = pd.read_csv("/home/prisb/projects/henry_hashtag_experiment/data/demuxlet/220817_scRNAseq_hashtag_library/C6D8/C6D8_demuxlet.BEST", sep="\t")
infile

# %%
#convert the BEST column

infile.replace(genotype_alias_dict, regex=True)
