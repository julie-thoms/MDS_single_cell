# %% [markdown]
# # single cell sequencing of T cells and HSC from MDS patients in an azacitidine trial

# %% [markdown]
# # Load packages and data files

# %%
import scanpy as sc
import warnings

# %%
warnings.filterwarnings("ignore")
sc.settings.set_figure_params(dpi=100, facecolor="white")

# %%
adata_healthy = sc.read_h5ad("data/healthy.h5ad")
adata_HSC = sc.read_h5ad("data/HSC_1.h5ad")
adata_Tcells = sc.read_h5ad("data/T_reclustered.h5ad")
adata_other = sc.read_h5ad("data/nonTnorHSC.h5ad")

# %%
adata_HSC

# %%
sc.pl.umap(adata_HSC, color=["celltype"])
