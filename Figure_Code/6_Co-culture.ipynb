# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import os

mpl.rcParams.update({
    # --- Fonts: keep text editable ---
    'pdf.fonttype': 'truetype',   # same as 42, ensures TrueType fonts
    'ps.fonttype': 'truetype',    # for EPS compatibility
    'svg.fonttype': 'none',       # keeps SVG text as text, not outlines

    # --- PDF structure: keep elements separate ---
    'pdf.compression': 0,         # prevents grouping/merging of vector paths
    'savefig.transparent': True,  # optional: preserves transparent backgrounds
    'savefig.bbox': 'tight',      # trims whitespace
    'savefig.pad_inches': 0.02,   # small padding for Illustrator bleed safety

    # --- General style niceties ---
    'font.sans-serif': ['Arial', 'Helvetica', 'DejaVu Sans'],
    'font.family': 'sans-serif'
})

from IPython.display import display, HTML
display(HTML("<style>.jp-Cell { margin-left: -20% !important; margin-right: -15% !important; }</style>"))
# Out:
# <style>.jp-Cell { margin-left: -20% !important; margin-right: -15% !important; }</style>

# %%
#Bar colours
treat_col = {0:'white',
            1: 'silver',
            2: '#808080'}

# %%
#----P18 plots----
#----Import data from Xioaheng
#Get sheet names
xls = pd.ExcelFile('../Data/P18_count_table_analysis.xls')
sheets18 = xls.sheet_names
sheets18.append('CB') #Add an extra dummy entry for spacing

# %%
#----Manually add initial cell ceeding number from original excel formulas
seed_no18 = {'CB':9222,
           'C1D1_HSC_suba':4831,
           'PD_subb':3255,
           'PD_subc':9000}

#----Manually add colours for dots
source_col18 = {'CB':'#cbcacc',
           'C1D1_HSC_suba':'#e2b8c4',
           'PD_subb':'#c4738a',
           'PD_subc':'#9f1c3e'}
#Manually add treatment dictionary (extract treatment codes from full df)
treat18 = {'R':'Rapa', 
         'V':'Vehicle', 
         '1AR':'1uM_AZA_Rapa', 
         '1A':'1uM_AZA', 
         '3AR':'3uM_AZA_Rapa', 
         '3A':'3uM_AZA'}

treat_co18 = {'R':3, 
         'V':0, 
         '1AR':4, 
         '1A':1, 
         '3AR':5, 
         '3A':2}

# %%
#Read in the data and perform calculations as neccesary

df18 = None
for s in sheets18[:-1]: #Can't iterate through extra CB entry lr data will get imported twice
    sd = pd.read_excel('../Data/P18_count_table_analysis.xls', sheet_name = s,  engine='xlrd', usecols = 'A:F')
    sd['Source'] = s
    sd['Cells_seeded'] = seed_no18[s]
    sd['Total_count'] = sd['mCD105- | Count']/sd['Beads-2 | Count']*10000
    sd['Total_normalized_to_seeding'] = sd['Total_count']/sd['Cells_seeded']
    sd['Treatment'] = sd['Unnamed: 0'].str.split('_').str[-3].replace(treat18)
    sd['x_coord'] = sd['Unnamed: 0'].str.split('_').str[-3].replace(treat_co18)

    #Find vehicle average
    veh_mean = sd.loc[sd['Unnamed: 0'].str.contains('_V_')]['Total_count'].mean()
    sd['Total_normalized_to_vehicle'] = sd['Total_count']/veh_mean*100

    sd = sd.loc[sd['Unnamed: 0'].str.contains('Specimen')]

    #Convert percentages
    sd['CD34pos'] = sd['CD34pos | Freq. of Parent'].str.split(' ').str[0].astype('float')
    sd['CD34neg'] = sd['CD34neg | Freq. of Parent'].str.split(' ').str[0].astype('float')
    
    if df18 is None:
        df18 = sd.copy()
    else:
        df18 = pd.concat([sd, df18], ignore_index = True)

df18
# Out:
# C:\Users\z3283497\AppData\Local\Temp\ipykernel_78960\2869223316.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sd['x_coord'] = sd['Unnamed: 0'].str.split('_').str[-3].replace(treat_co18)
# C:\Users\z3283497\AppData\Local\Temp\ipykernel_78960\2869223316.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sd['x_coord'] = sd['Unnamed: 0'].str.split('_').str[-3].replace(treat_co18)
# C:\Users\z3283497\AppData\Local\Temp\ipykernel_78960\2869223316.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sd['x_coord'] = sd['Unnamed: 0'].str.split('_').str[-3].replace(treat_co18)
# C:\Users\z3283497\AppData\Local\Temp\ipykernel_78960\2869223316.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sd['x_coord'] = sd['Unnamed: 0'].str.split('_').str[-3].replace(treat_co18)
#                               Unnamed: 0  Beads-2 | Count  mCD105- | Count  \
# 0      Specimen_001_PD_Sub C_R_4_026.fcs           4093.0            442.0
# 1      Specimen_001_PD_Sub C_R_5_027.fcs           4161.0            484.0
# 2      Specimen_001_PD_Sub C_R_6_028.fcs           3789.0            417.0
# 3      Specimen_001_PD_Sub C_V_1_023.fcs           4087.0            530.0
# 4      Specimen_001_PD_Sub C_V_2_024.fcs           4266.0            580.0
# 5      Specimen_001_PD_Sub C_V_3_025.fcs           4182.0            571.0
# 6   Specimen_001_PD_Sub C_1AR_10_032.fcs           3687.0            148.0
# 7   Specimen_001_PD_Sub C_1AR_11_033.fcs           3453.0            127.0
# 8   Specimen_001_PD_Sub C_1AR_12_034.fcs           3667.0            159.0
# 9     Specimen_001_PD_Sub C_1A_7_029.fcs           3325.0            160.0
# 10    Specimen_001_PD_Sub C_1A_8_030.fcs           3986.0            232.0
# 11    Specimen_001_PD_Sub C_1A_9_031.fcs           3849.0            215.0
# 12  Specimen_001_PD_Sub C_3AR_16_038.fcs           3399.0             37.0
# 13  Specimen_001_PD_Sub C_3AR_17_039.fcs           3462.0             35.0
# 14  Specimen_001_PD_Sub C_3AR_18_040.fcs           3579.0             46.0
# 15   Specimen_001_PD_Sub C_3A_13_035.fcs           3888.0             66.0
# 16   Specimen_001_PD_Sub C_3A_14_036.fcs           3381.0             57.0
# 17   Specimen_001_PD_Sub C_3A_15_037.fcs           3400.0             56.0
# 18     Specimen_001_PD_Sub b_V_1_012.fcs           3584.0            395.0
# 19     Specimen_001_PD_Sub b_V_2_013.fcs           3533.0            359.0
# 20     Specimen_001_PD_Sub b_V_3_014.fcs           3552.0            429.0
# 21    Specimen_001_PD_Sub b_1A_4_015.fcs           3459.0            383.0
# 22    Specimen_001_PD_Sub b_1A_5_016.fcs           3582.0            406.0
# 23    Specimen_001_PD_Sub b_1A_6_017.fcs           3547.0            399.0
# 24    Specimen_001_PD_Sub b_3A_7_020.fcs           3608.0            280.0
# 25    Specimen_001_PD_Sub b_3A_8_021.fcs           3616.0            243.0
# 26    Specimen_001_PD_Sub b_3A_9_022.fcs           3454.0            239.0
# 27         Specimen_001_C1D1_V_2_004.fcs           3577.0           1284.0
# 24            233.0                    16.1 %                    83.2 %
# 25            191.0                    20.2 %                    78.6 %
# 26            192.0                    18.0 %                    80.3 %
# 27           1033.0                    19.1 %                    80.5 %
# 28           1083.0                    17.4 %                    81.7 %
# 29           1235.0                    16.1 %                    83.4 %
# 30            861.0                    18.5 %                    80.9 %
# 31            841.0                    20.2 %                    79.2 %
# 32            838.0                    18.4 %                    81.0 %
# 33            665.0                    21.0 %                    78.3 %
# 34            570.0                    22.5 %                    76.8 %
# 35            561.0                    21.7 %                    77.6 %
# 36           4519.0                    25.2 %                    74.5 %
# 37           4048.0                    27.4 %                    72.2 %
# 38           3348.0                    27.6 %                    72.0 %
# 39           4461.0                    34.9 %                    64.6 %
# 40           4399.0                    35.2 %                    64.4 %
# 41           3502.0                    37.2 %                    62.3 %
# 42           2608.0                    21.1 %                    78.5 %
# 43           2959.0                    19.0 %                    80.6 %
# 44           2904.0                    21.3 %                    78.3 %
# 45           3595.0                    32.0 %                    67.5 %
# 46           3871.0                    27.5 %                    72.0 %
# 47           3856.0                    27.7 %                    71.8 %
# 48           1851.0                    18.1 %                    81.2 %
# 49           1661.0                    18.0 %                    81.1 %
# 50           1784.0                    18.0 %                    81.4 %
# 51           2241.0                    24.3 %                    75.1 %
# 52           2649.0                    22.7 %                    76.8 %
# 53           2089.0                    23.6 %                    76.1 %
#
#            Source  Cells_seeded   Total_count  Total_normalized_to_seeding  \
# 0         PD_subc          9000   1079.892499                     0.119988
# 1         PD_subc          9000   1163.181927                     0.129242
# 2         PD_subc          9000   1100.554236                     0.122284
# 3         PD_subc          9000   1296.794715                     0.144088
# 4         PD_subc          9000   1359.587436                     0.151065
# 5         PD_subc          9000   1365.375418                     0.151708
# 6         PD_subc          9000    401.410361                     0.044601
# 7         PD_subc          9000    367.796119                     0.040866
# 8         PD_subc          9000    433.596946                     0.048177
# 9         PD_subc          9000    481.203008                     0.053467
# 10        PD_subc          9000    582.037130                     0.064671
# 11        PD_subc          9000    558.586646                     0.062065
# 12        PD_subc          9000    108.855546                     0.012095
# 13        PD_subc          9000    101.097631                     0.011233
# 14        PD_subc          9000    128.527522                     0.014281
# 15        PD_subc          9000    169.753086                     0.018861
# 16        PD_subc          9000    168.589175                     0.018732
# 17        PD_subc          9000    164.705882                     0.018301
# 18        PD_subb          3255   1102.120536                     0.338593
# 19        PD_subb          3255   1016.133598                     0.312176
# 20        PD_subb          3255   1207.770270                     0.371051
# 21        PD_subb          3255   1107.256432                     0.340171
# 22        PD_subb          3255   1133.445003                     0.348217
# 23        PD_subb          3255   1124.894277                     0.345590
# 24        PD_subb          3255    776.053215                     0.238419
# 25        PD_subb          3255    672.013274                     0.206456
# 26        PD_subb          3255    691.951361                     0.212581
# 27  C1D1_HSC_suba          4831   3589.600224                     0.743035
# 28  C1D1_HSC_suba          4831   3726.096738                     0.771289
# 29  C1D1_HSC_suba          4831   4229.779937                     0.875550
# 30  C1D1_HSC_suba          4831   3131.253679                     0.648158
# 30       1uM_AZA      1.0                    81.363127     80.9    18.50
# 31       1uM_AZA      1.0                    80.241995     79.2    20.20
# 32       1uM_AZA      1.0                    77.450748     81.0    18.40
# 33       3uM_AZA      2.0                    63.120421     78.3    21.00
# 34       3uM_AZA      2.0                    56.014752     76.8    22.50
# 35       3uM_AZA      2.0                    53.814316     77.6    21.70
# 36          Rapa      3.0                    88.628968     74.5    25.20
# 37          Rapa      3.0                    81.256245     72.2    27.40
# 38          Rapa      3.0                    71.670564     72.0    27.60
# 39       Vehicle      0.0                   107.016461     64.6    34.90
# 40       Vehicle      0.0                   103.127655     64.4    35.20
# 41       Vehicle      0.0                    89.855884     62.3    37.20
# 42  1uM_AZA_Rapa      4.0                    53.399501     78.5    21.10
# 43  1uM_AZA_Rapa      4.0                    58.328714     80.6    19.00
# 44  1uM_AZA_Rapa      4.0                    59.214652     78.3    21.30
# 45       1uM_AZA      1.0                    85.809054     67.5    32.00
# 46       1uM_AZA      1.0                    81.712335     72.0    27.50
# 47       1uM_AZA      1.0                    81.379799     71.8    27.70
# 48  3uM_AZA_Rapa      5.0                    34.436159     81.2    18.10
# 49  3uM_AZA_Rapa      5.0                    33.156743     81.1    18.00
# 50  3uM_AZA_Rapa      5.0                    33.574015     81.4    18.00
# 51       3uM_AZA      2.0                    47.732660     75.1    24.30
# 52       3uM_AZA      2.0                    49.633093     76.8    22.70
# 53       3uM_AZA      2.0                    43.886948     76.1    23.60

# %%
#Now make some plots
fig, ax = plt.subplots(3, 6, figsize = (8, 6))
ax = ax.ravel()

width = 0.6

for i, c in enumerate(sheets18):
    data = df18.loc[(df18['Source']==c) & (df18['Treatment'].isin(['Vehicle', '1uM_AZA', '3uM_AZA']))]
    x = data['x_coord']
    y1 = data['Total_normalized_to_vehicle']
    y2 = data['CD34neg']
    y3 = data['Total_count']/data['Cells_seeded']

    ax[i].set_title(f'{c}')
    ax[i+6].set_title(f'{c}')
    ax[i+12].set_title(f'{c}')

    #Top row - cell count cf vehicle
    sns.barplot(data=data, x = 'x_coord', y = y1, ax = ax[i], width = width, errorbar=None,  edgecolor = 'k', hue = 'x_coord', palette = treat_col, legend=False)
    sns.stripplot(data=data, x = 'x_coord', y = y1, ax = ax[i], hue='Source', palette = source_col18, edgecolor = 'k', s=8, linewidth = 1)
    ax[i].set_xlim(-0.5,2.5)
    ax[i].set_ylim(0,150)
    ax[i].set_xticks([0,1,2])
    ax[i].set_xticklabels(['0', '1', '3'])
    ax[i].axhline(y=100, c='silver', ls='--', zorder=-10)
    ax[i].get_legend().remove()
    for d in ['top', 'right']:
        ax[i].spines[d].set_visible(False) 
    

    #Middle row - percent CD34%
    sns.barplot(data=data, x = 'x_coord', y = y2, ax = ax[i+6], width = width, errorbar=None, edgecolor = 'k', hue = 'x_coord', palette = treat_col, legend=False)
    sns.stripplot(data=data, x = 'x_coord', y = y2, ax = ax[i+6], hue='Source', palette = source_col18,  edgecolor = 'k', s=8, linewidth = 1)
    ax[i+6].set_xlim(-0.5,2.5)
    ax[i+6].set_ylim(0,50)
    ax[i+6].set_xticks([0,1,2])
    ax[i+6].set_xticklabels(['0', '1', '3'])
    ax[i+6].get_legend().remove()
    for d in ['top', 'right']:
        ax[i+6].spines[d].set_visible(False) 

    #Bottom row - raw counts
    sns.barplot(data=data, x = 'x_coord', y = y3, ax = ax[i+12], width = width, errorbar=None, edgecolor = 'k', hue = 'x_coord', palette = treat_col, legend=False)
    sns.stripplot(data=data, x = 'x_coord', y = y3, ax = ax[i+12], hue='Source', palette = source_col18,  edgecolor = 'k', s=8, linewidth = 1)
    ax[i+12].set_xlim(-0.5,2.5)
    ax[i+12].set_ylim(0,3)
    ax[i+12].set_xticks([0,1,2])
    ax[i+12].set_xticklabels(['0', '1', '3'])
    ax[i+12].axhline(y=1, c='silver', ls='--', zorder=-10)
    ax[i+12].get_legend().remove()
    for d in ['top', 'right']:
        ax[i+12].spines[d].set_visible(False) 

for i in range(17):
    if i == 0:
        ax[i].set_ylabel('Total cells (norm to veh)')
        ax[i].set_xlabel('')
    elif i == 6:
        ax[i].set_ylabel('%CD34 neg live cells')
        ax[i].set_xlabel('')
    elif i == 12:
        ax[i].set_ylabel('Fold expansion')
        ax[i].set_xlabel('')
    else:
        ax[i].set_ylabel('')
        ax[i].set_xlabel('')
        ax[i].set_yticklabels([])

#ax[4].set_axis_off()
#ax[10].set_axis_off()
#ax[16].set_axis_off()
ax[5].set_axis_off()
ax[11].set_axis_off()
ax[17].set_axis_off()


# # Add legends - turn off to keep spacing consistent
# for group, color in source_col18.items():
#     ax[5].scatter([], [], c=color, label=group, marker = 'o', edgecolor = 'k', s=80, linewidth = 1)
# ax[5].legend(title='Cell type', bbox_to_anchor=(0,1), loc="upper left", ncols = 1)

# # Add legends
# for group, color in treat_col.items():
#     ax[11].scatter([], [], c=color, label=group, marker = 's', edgecolor = 'k', s=80, linewidth = 1)
# ax[11].legend(title='Treatment', bbox_to_anchor=(0,1), loc="upper left", ncols = 1)



fig.tight_layout()
#fig.savefig('../Figures/6_P18_in_vitro_graphs_v2.pdf',bbox_inches='tight', format = 'pdf', dpi = 600)

# %%
#----P17 plots----
#----Import data from Xioaheng
#Get sheet names
xls = pd.ExcelFile('../Data/P17_count_table_analysis.xls')
sheets17 = xls.sheet_names
sheets17
# Out:
# ['CB', 'C1D8_l', 'C1D8_m', 'C1D8_n', 'PD_n']

# %%
#----Manually add initial cell seeding number from original excel formulas
seed_no17 = {'CB':14612,
           'C1D8_l':2825,
           'C1D8_m':4554,
           'C1D8_n':3840 ,
           'PD_n':10000}

#----Manually add colours for dots
source_col17 = {'CB':'#cbcacc',
           'C1D8_l':'#bbd2c6',
           'C1D8_m':'#77a48c',
           'C1D8_n':'#1c6840',
           'PD_n':'#1c6840'}

#Manually add treatment dictionary (extract treatment codes from full df)
treat17 = {'Veh':'Vehicle', 
         '1AZA':'1uM_AZA', 
         '3AZA':'3uM_AZA'}

treat_co17 = {'R':3, 
         'Veh':0, 
         '1AZA':1, 
         '3AZA':2}

# %%
#Read in the data and perform calculations as neccesary

df17 = None
for s in sheets17:
    sd = pd.read_excel('../Data/P17_count_table_analysis.xls', sheet_name = s,  engine='xlrd', usecols = 'A:F')
    sd['Source'] = s
    sd['Cells_seeded'] = seed_no17[s]
    sd['Total_count'] = sd['mCD105-hCD45+/Live | Count']/sd['Beads-2 | Count']*10000
    sd['Total_normalized_to_seeding'] = sd['Total_count']/sd['Cells_seeded']
    if s == 'CB':
        sd['Treatment'] = sd['Unnamed: 0'].str.split('_').str[-3].replace(treat17)
        sd['x_coord'] = sd['Unnamed: 0'].str.split('_').str[-3].replace(treat_co17)
    else:
        sd['Treatment'] = sd['Unnamed: 0'].str.split('_').str[-4].replace(treat17)
        sd['x_coord'] = sd['Unnamed: 0'].str.split('_').str[-4].replace(treat_co17)

    #Find vehicle average
    veh_mean = sd.loc[sd['Unnamed: 0'].str.contains('_Veh_')]['Total_count'].mean()
    sd['Total_normalized_to_vehicle'] = sd['Total_count']/veh_mean*100

    sd = sd.loc[sd['Unnamed: 0'].str.contains('Specimen')]

    #Convert percentages
    sd['CD34pos'] = sd['CD34pos | Freq. of Parent'].str.split(' ').str[0].astype('float')
    sd['CD34neg'] = sd['CD34neg | Freq. of Parent'].str.split(' ').str[0].astype('float')
    
    if df17 is None:
        df17 = sd.copy()
    else:
        df17 = pd.concat([sd, df17], ignore_index = True)

df17
# Out:
# C:\Users\z3283497\AppData\Local\Temp\ipykernel_78960\344634422.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sd['x_coord'] = sd['Unnamed: 0'].str.split('_').str[-3].replace(treat_co17)
# C:\Users\z3283497\AppData\Local\Temp\ipykernel_78960\344634422.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sd['x_coord'] = sd['Unnamed: 0'].str.split('_').str[-4].replace(treat_co17)
# C:\Users\z3283497\AppData\Local\Temp\ipykernel_78960\344634422.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sd['x_coord'] = sd['Unnamed: 0'].str.split('_').str[-4].replace(treat_co17)
# C:\Users\z3283497\AppData\Local\Temp\ipykernel_78960\344634422.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sd['x_coord'] = sd['Unnamed: 0'].str.split('_').str[-4].replace(treat_co17)
# C:\Users\z3283497\AppData\Local\Temp\ipykernel_78960\344634422.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sd['x_coord'] = sd['Unnamed: 0'].str.split('_').str[-4].replace(treat_co17)
#                               Unnamed: 0  Beads-2 | Count  \
# 0       Specimen_001_PD_Veh_n0_1_030.fcs           3666.0
# 1       Specimen_001_PD_Veh_n0_2_031.fcs           3678.0
# 2       Specimen_001_PD_Veh_n0_3_032.fcs           3740.0
# 3      Specimen_001_PD_1AZA_n0_4_033.fcs           3632.0
# 4      Specimen_001_PD_1AZA_n0_5_034.fcs           3648.0
# 5      Specimen_001_PD_1AZA_n0_6_035.fcs           3632.0
# 6      Specimen_001_PD_3AZA_n0_7_036.fcs           4834.0
# 7      Specimen_001_PD_3AZA_n0_8_037.fcs           5008.0
# 8      Specimen_001_PD_3AZA_n0_9_038.fcs           4995.0
# 11                        1294             1202                    6.11 %
# 12                        1092             1032                    4.30 %
# 13                         874              822                    4.35 %
# 14                         943              908                    2.76 %
# 15                         162              149                    6.79 %
# 16                         158              153                    1.27 %
# 17                         148              139                    4.73 %
# 18                        2053             1893                    6.67 %
# 19                        1693             1515                    8.86 %
# 20                        1950             1786                    6.97 %
# 21                        1948             1826                    5.44 %
# 22                        1493             1382                    6.30 %
# 23                        1629             1575                    2.46 %
# 24                        1397             1332                    3.94 %
# 25                         843              813                    2.97 %
# 26                        1019              985                    2.45 %
# 27                         679              474                    29.3 %
# 28                         530              380                    27.2 %
# 29                         618              482                    21.7 %
# 30                         642              469                    26.2 %
# 31                         837              643                    22.2 %
# 32                         814              598                    25.8 %
# 33                         417              321                    21.6 %
# 34                         510              403                    20.4 %
# 35                         402              285                    27.6 %
# 36                        8495             6343                    24.8 %
# 37                       12542             9221                    26.0 %
# 38                       10440             7691                    25.8 %
# 39                        8677             6568                    23.8 %
# 40                        7788             6280                    18.9 %
# 41                        7510             5975                    20.1 %
# 42                        6323             5261                    16.5 %
# 43                        5864             4910                    15.8 %
# 44                        4971             4065                    17.8 %
#
#    CD34pos | Freq. of Parent  Source  Cells_seeded   Total_count  \
# 0                     92.5 %    PD_n         10000   6710.310966
# 1                     92.3 %    PD_n         10000   6846.112017
# 2                     94.1 %    PD_n         10000   6911.764706
# 3                     90.5 %    PD_n         10000   6839.207048
# 4                     92.9 %    PD_n         10000   6532.346491
# 5                     94.2 %    PD_n         10000   6398.678414
# 6                     90.0 %    PD_n         10000   1977.658254
# 7                     91.1 %    PD_n         10000   2058.706070
# 8                     87.7 %    PD_n         10000   2252.252252
# 9                     94.7 %  C1D8_n          3840   2158.286778
# 10                    93.8 %  C1D8_n          3840   1972.436012
# 11                    92.9 %  C1D8_n          3840   2276.165347
# 12                    94.5 %  C1D8_n          3840   2126.582278
# 13                    94.1 %  C1D8_n          3840   1799.835255
# 14                    96.3 %  C1D8_n          3840   1977.768456
# 15                    92.0 %  C1D8_n          3840    327.074500
# 16                    96.8 %  C1D8_n          3840    314.490446
# 17                    93.9 %  C1D8_n          3840    300.446610
# 18                    92.2 %  C1D8_m          4554   3060.981065
# 19                    89.5 %  C1D8_m          4554   2580.792683
# 20                    91.6 %  C1D8_m          4554   2937.631817
# 21                    93.7 %  C1D8_m          4554   3023.905619
# 22                    92.6 %  C1D8_m          4554   2685.734844
# 23                    96.7 %  C1D8_m          4554   2716.358179
# 24                    95.3 %  C1D8_m          4554   2302.241266
# 25                    96.4 %  C1D8_m          4554   2049.100632
# 26                    96.7 %  C1D8_m          4554   2104.067727
# 27                    69.8 %  C1D8_l          2825   1201.557247
# 28                    71.7 %  C1D8_l          2825    985.496467
# 29                    78.0 %  C1D8_l          2825   1135.820621
# 30                    73.1 %  C1D8_l          2825   1179.279941
# 31                    76.8 %  C1D8_l          2825   1452.872765
# 32                    73.5 %  C1D8_l          2825   1308.892105
# 12                    99.576373     94.5     4.30
# 13                    84.276573     94.1     4.35
# 14                    92.608225     96.3     2.76
# 15                    15.315134     92.0     6.79
# 16                    14.725891     96.8     1.27
# 17                    14.068294     93.9     4.73
# 18                   107.034725     92.2     6.67
# 19                    90.243759     89.5     8.86
# 20                   102.721516     91.6     6.97
# 21                   105.738291     93.7     5.44
# 22                    93.913319     92.6     6.30
# 23                    94.984139     96.7     2.46
# 24                    80.503524     95.3     3.94
# 25                    71.651839     96.4     2.97
# 26                    73.573899     96.7     2.45
# 27                   108.480532     69.8    29.30
# 28                    88.973855     71.7    27.20
# 29                   102.545613     78.0    21.70
# 30                   106.469263     73.1    26.20
# 31                   131.170121     76.8    22.20
# 32                   118.171075     73.5    25.80
# 33                    62.632055     77.0    21.60
# 34                    75.285274     79.0    20.40
# 35                    69.822777     70.9    27.60
# 36                    85.382712     74.7    24.80
# 37                   114.511479     73.5    26.00
# 38                   100.105809     73.7    25.80
# 39                    81.887995     75.7    23.80
# 40                    73.498180     80.6    18.90
# 41                    72.685699     79.6    20.10
# 42                    57.870014     83.2    16.50
# 43                    55.363686     83.7    15.80
# 44                    47.786301     81.8    17.80

# %%
#Now make some plots
fig, ax = plt.subplots(3, 6, figsize = (8, 6))
ax = ax.ravel()

width = 0.6

for i, c in enumerate(sheets17):
    data = df17.loc[(df17['Source']==c) & (df17['Treatment'].isin(['Vehicle', '1uM_AZA', '3uM_AZA']))]
    x = data['x_coord']
    y1 = data['Total_normalized_to_vehicle']
    y2 = data['CD34neg']
    y3 = data['Total_count']/data['Cells_seeded']

    ax[i].set_title(f'{c}')
    ax[i+6].set_title(f'{c}')
    ax[i+12].set_title(f'{c}')

    #Top row - cell count cf vehicle
    sns.barplot(data=data, x = 'x_coord', y = y1, ax = ax[i], width = width, errorbar=None,  edgecolor = 'k', hue = 'x_coord', palette = treat_col, legend=False)
    sns.stripplot(data=data, x = 'x_coord', y = y1, ax = ax[i], hue='Source', palette = source_col17, edgecolor = 'k', s=8, linewidth = 1)
    ax[i].set_xlim(-0.5,2.5)
    ax[i].set_ylim(0,150)
    ax[i].set_xticks([0,1,2])
    ax[i].set_xticklabels(['0', '1', '3'])
    ax[i].axhline(y=100, c='silver', ls='--', zorder=-10)
    ax[i].get_legend().remove()
    for d in ['top', 'right']:
        ax[i].spines[d].set_visible(False) 
    

    #Middle row - percent CD34%
    sns.barplot(data=data, x = 'x_coord', y = y2, ax = ax[i+6], width = width, errorbar=None, edgecolor = 'k', hue = 'x_coord', palette = treat_col, legend=False)
    sns.stripplot(data=data, x = 'x_coord', y = y2, ax = ax[i+6], hue='Source', palette = source_col17,  edgecolor = 'k', s=8, linewidth = 1)
    ax[i+6].set_xlim(-0.5,2.5)
    ax[i+6].set_ylim(0,50)
    ax[i+6].set_xticks([0,1,2])
    ax[i+6].set_xticklabels(['0', '1', '3'])
    ax[i+6].get_legend().remove()
    for d in ['top', 'right']:
        ax[i+6].spines[d].set_visible(False) 

    #Bottom row - raw counts
    sns.barplot(data=data, x = 'x_coord', y = y3, ax = ax[i+12], width = width, errorbar=None, edgecolor = 'k', hue = 'x_coord', palette = treat_col, legend=False)
    sns.stripplot(data=data, x = 'x_coord', y = y3, ax = ax[i+12], hue='Source', palette = source_col17,  edgecolor = 'k', s=8, linewidth = 1)
    ax[i+12].set_xlim(-0.5,2.5)
    ax[i+12].set_ylim(0,4)
    ax[i+12].set_xticks([0,1,2])
    ax[i+12].set_xticklabels(['0', '1', '3'])
    ax[i+12].axhline(y=1, c='silver', ls='--', zorder=-10)
    ax[i+12].get_legend().remove()
    for d in ['top', 'right']:
        ax[i+12].spines[d].set_visible(False) 

for i in range(17):
    if i == 0:
        ax[i].set_ylabel('Total cells (norm to veh)')
        ax[i].set_xlabel('')
    elif i == 6:
        ax[i].set_ylabel('%CD34 neg live cells')
        ax[i].set_xlabel('')
    elif i == 12:
        ax[i].set_ylabel('Fold expansion')
        ax[i].set_xlabel('')
    else:
        ax[i].set_ylabel('')
        ax[i].set_xlabel('')
        ax[i].set_yticklabels([])

ax[5].set_axis_off()
ax[11].set_axis_off()
ax[17].set_axis_off()



fig.tight_layout()
#fig.savefig('../Figures/6_P17_in_vitro_graphs_v2.pdf',bbox_inches='tight', format = 'pdf', dpi = 600)

# %%
#Now want to get stats - have exported Xiaoheng's ordinary one-way ANOVA data with multiple comparisons - pull in here to combine it all

# %%
pop_dict = dict(zip(['l', 'm', 'n', 'control', 'suba', 'subb', 'subc'], ['19', '4', '0', 'control', '13', '15', '9']))

# %%
directory = '../Data/Fig6_stats/'

df = None

for f in os.listdir(directory):
    detail = f.split('of')[1]
    pat = detail.split('_')[0]
    tp = detail.split('_')[1]
    if tp == 'mixed CB':
        tp = 'CB'
        pop = 'control'
    else:
       pop =  detail.split('_')[2]

    if 'CD34neg_percentage' in detail:
        comp = 'percent_CD34neg'
    elif 'seeding' in detail:
        comp = 'normalised_to_seeding'
    elif 'Vehicle' in detail:
        comp = 'normalised_to_vehicle'
    
    filename = os.path.join(directory, f)
    df0 = pd.read_csv(filename)
    id = df0.iloc[:,0].to_dict()
    for key, value in id.items():
        if pd.notna(value):
            if 'multiple comparisons' in value:
                col1 = key
            if 'details' in value:
                col2 = key
            if 'Compact' in value:
                col3 = key
    
    df1 = df0.iloc[col1:col2-1]
    df1.columns = df1.iloc[0]
    df1 = df1.iloc[1:].reset_index(drop=True)
    df1 = df1.dropna(axis=1)
     
    df2 = df0.iloc[col2:col3-1]
    df2.columns = df2.iloc[0]
    df2 = df2.iloc[1:].reset_index(drop=True)
    df2 = df2.dropna(axis=1)
    
    df3 = pd.merge(df2, df1)
    df3 = df3.drop(columns = 'Tukey\'s multiple comparisons test')

    df3['Patient'] = pat
    df3['Population'] = pop
    df3['Timepoint'] = tp
    df3['Analysis'] = comp

    df3 = df3.loc[df3['Test details'].isin(['  Vehicle vs. 1uM AZA', '  Vehicle vs. 3uM AZA', '  1uM AZA vs. 3uM AZA'])]

    if df is None:
        df = df3.copy()
    else:
        df = pd.concat([df, df3], ignore_index = True) 

df.columns = [ 'Test details', 
              'Mean 1',             
              'Mean 2',
               'Mean diff.',        
              'SE of diff.',                 
              'n1',
                       'n2',                  
              'q',                 
              'DF',
               '95.00% CI of diff.',   
              'Below threshold?',            
              'Summary',
             'Adjusted P Value',                  
              'Columns_compared',            
              'Patient',
               'Population',          
              'Timepoint',
             'Analysis']  

df['Population2'] = df['Population'].replace(pop_dict)

df = df[['Patient', 'Population', 'Population2', 'Timepoint', 'Analysis','Test details', 'Mean 1', 'Mean 2', 'Mean diff.', 'SE of diff.', 'n1','n2', 'q', 'DF', '95.00% CI of diff.', 'Below threshold?', 'Summary', 'Adjusted P Value', 'Columns_compared']]  
#df.to_excel('../Figures/Figure6_stats_summary.xlsx', index = None)

# %%
#Plot just expansion with vehicle
#Now make some plots
fig, ax = plt.subplots(1,2, figsize = (4, 2))


width = 0.6

for i, c in enumerate(sheets18):
    data = df18.loc[(df18['Source']==c) & (df18['Treatment'].isin(['Vehicle']))]
    x = i
    y = data['Total_count']/data['Cells_seeded']


    #Bottom row - raw counts
    sns.barplot(data=data, x = x, y = y, ax = ax[0], width = width, errorbar=None, edgecolor = 'k', color = 'white',  legend=False)
    sns.stripplot(data=data, x = x, y = y, ax = ax[0], hue='Source', palette = source_col18,  edgecolor = 'k', s=8, linewidth = 1)
    ax[0].set_xlim(-0.5,4.5)
    ax[0].set_ylim(0,3)
    ax[0].set_xticks([0,1,2,3, 4])
    ax[0].set_yticks([0,1,2,3])
    ax[0].set_xticklabels(['CB', 'CL13', 'CL15', 'CL9', 'CB'])
    ax[0].axhline(y=1, c='silver', ls='--', zorder=-10)
    ax[0].get_legend().remove()
    ax[0].set_ylabel('Fold expansion')
    for d in ['top', 'right']:
        ax[0].spines[d].set_visible(False) 

for i, c in enumerate(sheets17):
    data = df17.loc[(df17['Source']==c) & (df17['Treatment'].isin(['Vehicle']))]
    x = i
    y = data['Total_count']/data['Cells_seeded']


    #Bottom row - raw counts
    sns.barplot(data=data, x = x, y = y, ax = ax[1], width = width, errorbar=None, edgecolor = 'k', color = 'white',  legend=False)
    sns.stripplot(data=data, x = x, y = y, ax = ax[1], hue='Source', palette = source_col17,  edgecolor = 'k', s=8, linewidth = 1)
    ax[1].set_xlim(-0.5,4.5)
    ax[1].set_ylim(0,3)
    ax[1].set_xticks([0,1,2,3, 4])
    ax[1].set_yticks([0,1,2,3, 4])
    ax[1].set_xticklabels(['CB', 'CL19', 'CL4', 'CL0', 'CL0'])
    ax[1].axhline(y=1, c='silver', ls='--', zorder=-10)
    ax[1].get_legend().remove()
    ax[1].set_ylabel('Fold expansion')
    for d in ['top', 'right']:
        ax[1].spines[d].set_visible(False) 

fig.tight_layout()

#fig.savefig('../Figures/6_P18_P17_in_vitro_graphs_expansion_vehicle_v2.pdf',bbox_inches='tight', format = 'pdf', dpi = 600)
